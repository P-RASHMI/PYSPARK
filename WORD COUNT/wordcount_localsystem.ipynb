# %%
'''
@Author: Rashmi
@Date: 2021-11-17 1:33
@Last Modified by: Rashmi
@Last Modified time: 2021-11-17 1:41
@Title :Write a Python program to perform word count by taking the text file locally  
'''
textfile = sc.textFile("file:///home/lenovo/textfile.txt")
words = textfile.flatMap(lambda line: line.split(" "))
wordcount = words.map(lambda word : (word,1)).reduceByKey(lambda a,b:a+b)  
wordcount.collect()
# Out:
# [('in', 3),
#  ('sky', 1),
#  ('cow', 2),
#  ('fly', 1),
#  ('have', 1),
#  ('pie', 1),
#  ('Hi', 4),
#  ('this', 4),
#  ('is', 4),
#  ('execute', 2),
#  ('of', 4),
#  ('we', 2),
#  ('count', 2),
#  ('input', 1),
#  ('are', 1),
#  ('Birdie', 2),
#  ('the', 4),
#  ('laid', 1),
#  ('a', 2),
#  ('turdie', 1),
#  ('my', 2),
#  ('eye', 2),
#  ('If', 1),
#  ('could', 1),
#  ('I’d', 1),
#  ('sample', 2),
#  ('program', 2),
#  ('for', 2),
#  ('wordcount', 4),
#  ('to', 3),
#  ('get', 2),
#  ('words', 3),
#  ('data', 1),
#  ('incremented', 1),
#  ('hi', 1),
#  ('hello', 1),
#  ('welcome', 1),
#  ('spark', 1)]
